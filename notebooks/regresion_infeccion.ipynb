# %%
import pandas as pd

# %%
a = ["SE-01","SE-01","SE-01","SE-01","SE-01","SE-01","SE-05","SE-05","SE-09","SE-09","SE-09","SE-09","SE-10","SE-10","SE-13","SE-13","SE-13","SE-14","SE-14","SE-14","SE-14","SE-14","SE-14","SE-15","SE-15","SE-16","SE-17","SE-17","SE-18","SE-18","SE-18","SE-18","SE-18","SE-19","SE-19","SE-19","SE-20","SE-20","SE-21","SE-21","SE-21","SE-21","SE-21","SE-21","SE-22","SE-23","SE-23","SE-23","SE-23","SE-24","SE-24","SE-26","SE-26","MA-17","SE-27","SE-29","SE-30","SE-30","SE-30","SE-30","SE-30","SE-31","SE-32","SE-34","SE-34","SE-34","SE-34","SE-34","SE-35","SE-35","SE-35","SE-35","SE-35","SE-35","SE-39","SE-39","SE-39","SE-39","SE-39","SE-41","SE-41","SE-46","SE-46","SE-46","SE-46","SE-46","SE-46","SE-47","SE-47","SE-47","SE-47","SE-47","SE-47","SE-50","SE-50","SE-50","SE-51","SE-51","SE-51","SE-51","SE-53","SE-53","SE-53","SE-53","SE-55","SE-55","SE-55","SE-57","SE-57","SE-57","SE-57","SE-57","SE-57","MA-01","MA-01","MA-01","MA-01","MA-02","MA-02","MA-02","MA-02","MA-02","MA-03","MA-03","MA-03","MA-03","MA-03","MA-03","MA-03","MA-03","MA-03","MA-03","MA-03","MA-03","MA-04","MA-04","MA-04","MA-05","MA-05","MA-05","MA-06","MA-06","MA-06","MA-07","MA-07","MA-07","MA-07","MA-08","MA-08","MA-08","MA-08","MA-09","MA-09","MA-09","MA-09","MA-10","MA-10","MA-11","MA-11","MA-11","MA-11","MA-11","MA-12","MA-12","MA-12","MA-12","MA-13","MA-13","MA-14","MA-14","MA-14","MA-14","MA-14","MA-15","MA-15","MA-15","MA-15","MA-16","MA-16","MA-16","MA-16","MA-16","MA-16","MA-17","MA-17","MA-18","MA-19","MA-19","MA-19","MA-19","MA-20","MA-20","MA-20","MA-20","MA-21","MA-21","MA-21","MA-21","MA-21","MA-21","MA-21","MA-22","MA-22","MA-22","MA-23","MA-23","MA-23","MA-23","MA-23","MA-24","MA-24","MA-24","MA-25","MA-25","MA-25","MA-25","MA-25","MA-26","MA-26","MA-27","MA-27","MA-27","MA-27","MA-27","MA-28","MA-28","MA-28","MA-28","MA-28","MA-29","MA-29","MA-29","MA-29","MA-30","MA-30","MA-30","MA-31","MA-31","MA-31","MA-32","MA-32","MA-32","MA-33","MA-33","MA-33","MA-33","MA-33","MA-34","MA-34","MA-34","MA-34","MA-35","MA-35","MA-36","MA-36","MA-37","MA-38","MA-38","MA-38","MA-39","MA-39","MA-39","MA-39","MA-39","ZE-01","ZE-01","ZE-01","ZE-02","ZE-02","ZE-03","ZE-03","ZE-03","ZE-03","ZE-04","ZE-04","ZE-04","ZE-05","ZE-05","ZE-05","ZE-05","ZE-06","ZE-06","ZE-06","ZE-06","ZE-06","ZE-07","ZE-07","ZE-07","ZE-08","ZE-08","ZE-08","ZE-08","ZE-09","ZE-10","ZE-10","ZE-11","ZE-11","ZE-12","ZE-12","ZE-13","ZE-13","ZE-13","ZE-14","ZE-14","ZE-14","ZE-14","ZE-15","ZE-15","ZE-15","ZE-15","ZE-16","ZE-16","ZE-16","ZE-16","ZE-18","ZE-19","ZE-20","ZE-20","ZE-20","ZE-20","ZE-20","ZE-20","ZE-20","ZE-21","ZE-21","ZE-21","ZE-25","ZE-25","ZE-25","ZE-25","ZE-27","ZE-27","ZE-27","ZE-27","ZE-28","ZE-30","ZE-30","ZE-30","ZE-30","ZE-31","ZE-33","ZE-33","ZE-33","ZE-33","ZE-34","ZE-34","ZE-35","ZE-36","ZE-36","ZE-37","ZE-37","ZE-37","ZE-37","ZE-38","ZE-38","ZE-38","ZE-39","ZE-39","ZE-40","ZE-41","ZE-41","ZE-43","ZE-43","ZE-43","ZE-43","ZE-43","ZE-44","ZE-44","ZE-46","ZE-46"]

# %%
len(set(a))
# Out:
# 109

# %%
base_path = '../../../Base_18_03_2020.csv'

# %%
column_types = {
    'GENDER': 'category', 
    'AGE': 'float64', 
    're_G_trich': 'category', 
    're_G_Asc': 'category', 
    're_G_Hook': 'category', 
    're_H_Enter': 'category',
    're_H_Schis': 'category', 
    're_H_Hym_n': 'category', 
    're_H_Hym_d': 'category', 
    'sum_G_Stro': 'float64', 
    'sum_G_Tric': 'float64',
    'sum_G_Asc': 'float64', 
    'sum_G_HOOK': 'float64', 
    'sum_H_Ente': 'float64', 
    'sum_H_Schi': 'float64', 
    'sum_H_Hym_': 'float64',
    'sum_H_Hy_1': 'float64', 
    'si_G_Stron': 'category', 
    'si_G_Trich': 'category', 
    'si_G_Asc': 'category', 
    'si_G_Hook': 'category',
    'si_H_Enter': 'category', 
    'si_H_schis': 'category', 
    'si_H_hym_n': 'category', 
    'si_H_hym_d': 'category', 
    'riq_Geoh': 'float64',
    'riq_helm': 'float64', 
    'p_G_Strong': 'float64', 
    'p_G_Trich': 'float64', 
    'p_G_Asc': 'float64', 
    'p_G_HOOK': 'float64',
    'p_H_Enter': 'float64', 
    'p_H_Schis': 'float64', 
    'p_H_hym_n': 'float64', 
    'p_H_hym_d': 'float64', 
    'sh_geohel': 'float64',
    'sh_helm': 'float64', 
    'geohel_dom': 'category', 
    'Re_hous_nu': 'float64', 
    'num_indiv': 'float64', 
    're_G_stron': 'category',
       'ind_tip1_G': 'category', 
    'ind_tip1_H': 'category', 
    'p_tip1_G': 'float64', 
    'p_tip1_H': 'float64', 
    'ind_inf_Ge': 'float64',
    'ind_inf_He': 'float64', 
    'n_Geo_mean': 'float64', 
    'n_Hel_mean': 'float64', 
    'HOOKWORM_h': 'float64', 
    'HGH_x_50': 'float64',
    'r_huev_hoo': 'float64', 
    'Roof': 'category', 
    'Floor': 'category', 
    'Wall': 'category', 
    'Electricit': 'category', 
    'Radio': 'category',
    'Domestic a': 'category', 
    'Toilet': 'category', 
    'Drinking w': 'category', 
    'Drinking_1': 'category', 
    'Bath': 'category',
    'Water cook': 'category', 
    'Hand washi': 'category', 
    'Miembros_': 'float64', 
    'n_geo_stde': 'float64', 
    'n_Hel_stde': 'float64',
    're_hgh50': 'float64', 
    'sum_hgh50': 'float64', 
    'Prev_FO': 'float64', 
    'Prev_piel': 'float64', 
    'riego_ingr': 'float64',
    'riesgo_ele': 'category', 
    'Riesgo_wat': 'category', 
    'rieg_w2': 'category', 
    'riesg_w_2': 'category', 
    'riesg_w_3': 'category',
    'Ri_ingre': 'float64', 
    'NDVI': 'float64', 
    'Prec': 'float64', 
    'ri_bfd': 'float64', 
    'ri_orcd_n': 'float64', 
    'Ri_prec': 'float64',
    'Ri_NumInd': 'float64', 
    'BSI_n': 'float64', 
    'MSI_n': 'float64', 
    'NDBI_n': 'float64', 
    'BLDFIE_n': 'float64', 
    'BDRIC_n': 'float64',
    'CECSOL_n': 'float64', 
    'Clyp_n': 'float64', 
    'Crfvol_n': 'float64', 
    'Ocstha_n': 'float64', 
    'SLTppt_n': 'float64', 
    'Phihox_n': 'float64',
    'Phikcl_n': 'float64', 
    'Temp_n': 'float64'
}

# %%
raw_df = pd.read_csv(base_path, dtype=column_types, header=0, na_values=[' ', '*', ''])

# %%
raw_df.dtypes
# Out:
# Indv. CODE      object
# HOUSE_n_or      object
# House_n_gl       int64
# GENDER        category
# AGE            float64
#                 ...
# Ocstha_n       float64
# SLTppt_n       float64
# Phihox_n       float64
# Phikcl_n       float64
# Temp_n         float64
# Length: 111, dtype: object

# %%
non_columns = 'G_STRONG G_TRICH G_ASCAR G_H00K H_ENTER H_SCHIST H_HYM_NA H_HYM_D HOUSE_n_or House_n_gl DATE_Coll MyData_lat MyData_lon'
non_columns = non_columns.split() + ['Indv. CODE']

cleaned_df = raw_df.drop(columns=non_columns)

# %%
infeccion_piel = cleaned_df.Prev_piel.copy()
infeccion_fecoral = cleaned_df.Prev_FO.copy()
predictoras = cleaned_df.drop(columns=['Prev_piel', 'Prev_FO'])

# %%
predictoras.columns
# Out:
# Index(['GENDER', 'AGE', 're_G_trich', 're_G_Asc', 're_G_Hook', 're_H_Enter',
#        're_H_Schis', 're_H_Hym_n', 're_H_Hym_d', 'sum_G_Stro', 'sum_G_Tric',
#        'sum_G_Asc', 'sum_G_HOOK', 'sum_H_Ente', 'sum_H_Schi', 'sum_H_Hym_',
#        'sum_H_Hy_1', 'si_G_Stron', 'si_G_Trich', 'si_G_Asc', 'si_G_Hook',
#        'si_H_Enter', 'si_H_schis', 'si_H_hym_n', 'si_H_hym_d', 'riq_Geoh',
#        'riq_helm', 'p_G_Strong', 'p_G_Trich', 'p_G_Asc', 'p_G_HOOK',
#        'p_H_Enter', 'p_H_Schis', 'p_H_hym_n', 'p_H_hym_d', 'sh_geohel',
#        'sh_helm', 'geohel_dom', 'Re_hous_nu', 'num_indiv', 're_G_stron',
#        'ind_tip1_G', 'ind_tip1_H', 'p_tip1_G', 'p_tip1_H', 'ind_inf_Ge',
#        'ind_inf_He', 'n_Geo_mean', 'n_Hel_mean', 'HOOKWORM_h', 'HGH_x_50',
#        'r_huev_hoo', 'Roof', 'Floor', 'Wall', 'Electricit', 'Radio',
#        'Domestic a', 'Toilet', 'Drinking w', 'Drinking_1', 'Bath',
#        'Water cook', 'Hand washi', 'Miembros_', 'n_geo_stde', 'n_Hel_stde',
# ...

# %%
predictoras.Bath.isna().sum()
# Out:
# 8

# %% [markdown]
# ### Aplicamos **One Hot Encoding** en variables categoricas

# %%
from pandas import get_dummies

# %%
one_hot_predictors = get_dummies(predictoras)

# %%
len(predictoras)
# Out:
# 370

# %%
len(one_hot_predictors)
# Out:
# 370

# %%
print(list(one_hot_predictors.columns))
# Out:
# ['AGE', 'sum_G_Stro', 'sum_G_Tric', 'sum_G_Asc', 'sum_G_HOOK', 'sum_H_Ente', 'sum_H_Schi', 'sum_H_Hym_', 'sum_H_Hy_1', 'riq_Geoh', 'riq_helm', 'p_G_Strong', 'p_G_Trich', 'p_G_Asc', 'p_G_HOOK', 'p_H_Enter', 'p_H_Schis', 'p_H_hym_n', 'p_H_hym_d', 'sh_geohel', 'sh_helm', 'Re_hous_nu', 'num_indiv', 'p_tip1_G', 'p_tip1_H', 'ind_inf_Ge', 'ind_inf_He', 'n_Geo_mean', 'n_Hel_mean', 'HOOKWORM_h', 'HGH_x_50', 'r_huev_hoo', 'Miembros_', 'n_geo_stde', 'n_Hel_stde', 're_hgh50', 'sum_hgh50', 'riego_ingr', 'Ri_ingre', 'NDVI', 'Prec', 'ri_bfd', 'ri_orcd_n', 'Ri_prec', 'Ri_NumInd', 'BSI_n', 'MSI_n', 'NDBI_n', 'BLDFIE_n', 'BDRIC_n', 'CECSOL_n', 'Clyp_n', 'Crfvol_n', 'Ocstha_n', 'SLTppt_n', 'Phihox_n', 'Phikcl_n', 'Temp_n', 'GENDER_F', 'GENDER_M', 're_G_trich_0', 're_G_trich_1', 're_G_Asc_0', 're_G_Asc_1', 're_G_Hook_0', 're_G_Hook_1', 're_H_Enter_0', 're_H_Enter_1', 're_H_Schis_0', 're_H_Schis_1', 're_H_Hym_n_0', 're_H_Hym_n_1', 're_H_Hym_d_0', 'si_G_Stron_0', 'si_G_Stron_1', 'si_G_Trich_0', 'si_G_Tric
# ...

# %%
one_hot_predictors.columns.Drinking_1
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-15-04ae030bc6ab> in <module>
# ----> 1 one_hot_predictors.columns.Drinking_1
#
# AttributeError: 'Index' object has no attribute 'Drinking_1'

# %%
na_count = [k for k, v in enumerate(one_hot_predictors.isna().sum()) if v != 0]
indexes = list(one_hot_predictors.isna().sum().index)
na_variables = [indexes[k] for k in na_count]

# %%
one_hot_predictors.n_geo_stde = one_hot_predictors.n_geo_stde.fillna(one_hot_predictors.n_geo_stde.mean())
one_hot_predictors.n_Hel_stde = one_hot_predictors.n_Hel_stde.fillna(one_hot_predictors.n_Hel_stde.mean())


one_hot_predictors.re_hgh50 = one_hot_predictors.re_hgh50.fillna(0)
one_hot_predictors.HGH_x_50 = one_hot_predictors.HGH_x_50.fillna(0)

# %%
na_variables
# Out:
# []

# %% [markdown]
# ## Una vez que limpiamos los datos, entrenamos el modelo

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
model = RandomForestRegressor()

# %%
model.fit(one_hot_predictors, infeccion_piel)
# Out:
# RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=None, max_features='auto', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=100, n_jobs=None, oob_score=False,
#                       random_state=None, verbose=0, warm_start=False)

# %%
infeccion_piel.plot.hist()

# %%
from sklearn.metrics import mean_squared_error

y_pred = model.predict(one_hot_predictors)
mean_squared_error(infeccion_piel, y_pred)
# Out:
# 0.00011089978324324339

# %% [markdown]
# ### Hacemos un cross validation

# %%
import numpy as np
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import train_test_split 

def stats(xs, ts, model, n_splits=5):
    scores = cross_val_score(model, xs, ts, cv=n_splits, scoring='neg_mean_squared_error')

    scores = np.sqrt(-scores)

    mean = scores.mean()
    std_dev = scores.std()

    return scores, mean, std_dev


def print_stats(scores, mean, std_dev, title='Stats'):
    print()
    print(title)
    print('-' * len(title))
    print('')
    print('Model Scores: ', scores)
    print('Mean Score: ', mean)
    print('Standard Deviation of Score: ', std_dev)

# %%
scores, mean, std_dev = stats(one_hot_predictors, infeccion_piel, RandomForestRegressor())

# %%
print_stats(scores, mean, std_dev)
# Out:
# Stats
# -----
#
# Model Scores:  [0.09460468 0.03003575 0.1005248  0.05506701 0.12936948]
# Mean Score:  0.08192034618375299
# Standard Deviation of Score:  0.03513275326066268

# %%
from xgboost import XGBRegressor

# %%
scores, mean, std_dev = stats(one_hot_predictors, infeccion_piel, XGBRegressor(n_estimators=90, max_depth=40, learning_rate=0.05))

# %%
print_stats(scores, mean, std_dev)
# Out:
# Stats
# -----
#
# Model Scores:  [0.09225438 0.11750561 0.08189685 0.04304076 0.13110061]
# Mean Score:  0.09315964230464391
# Standard Deviation of Score:  0.03056735298552958

# %% [markdown]
# ## Analizamos las features para INFECCION de PIEL

# %%
import shap
import xgboost
shap.initjs()
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script>!function(t){function e(r){if(n[r])return n[r].exports;var i=n[r]={i:r,l:!1,exports:{}};return t[r].call(i.exports,i,i.exports,e),i.l=!0,i.exports}var n={};return e.m=t,e.c=n,e.i=function(t){return t},e.d=function(t,n,r){e.o(t,n)||Object.defineProperty(t,n,{configurable:!1,enumerable:!0,get:r})},e.n=function(t){var n=t&&t.__esModule?function(){return t.default}:function(){return t};return e.d(n,"a",n),n},e.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},e.p="",e(e.s=410)}([function(t,e,n){"use strict";function r(t,e,n,r,o,a,u,c){if(i(e),!t){var s;if(void 0===e)s=new Error("Minified exception occurred; use the non-minified dev environment for the full error message and additional helpful warnings.");else{var l=[n,r,o,a,u,c],f=0;s=new Error(e.replace(/%s/g,function(){return l[f++]})),s.name="Invariant Violation"}throw s.framesToPop=1,s}}var i=function(t){};t.exports=r},function(t,e,n){"use strict
# ...

# %%
bacteria_variables = ['sum_G_Stro', 'sum_G_Tric', 'sum_G_Asc', 'sum_G_HOOK', 'sum_H_Ente', 'sum_H_Schi', 'sum_H_Hym_', 'sum_H_Hy_1', 'riq_Geoh', 'riq_helm', 'p_G_Strong', 'p_G_Trich', 'p_G_Asc', 'p_G_HOOK', 'p_H_Enter', 'p_H_Schis', 'p_H_hym_n', 'p_H_hym_d', 'sh_geohel', 'sh_helm', 'Re_hous_nu', 'num_indiv', 'p_tip1_G', 'p_tip1_H', 'ind_inf_Ge', 'ind_inf_He', 'n_Geo_mean', 'n_Hel_mean', 'HOOKWORM_h', 'HGH_x_50', 'r_huev_hoo', 'n_geo_stde', 'n_Hel_stde', 're_hgh50', 'sum_hgh50', 're_G_trich_0', 're_G_trich_1', 're_G_Asc_0', 're_G_Asc_1', 're_G_Hook_0', 're_G_Hook_1', 're_H_Enter_0', 're_H_Enter_1', 're_H_Schis_0', 're_H_Schis_1', 're_H_Hym_n_0', 're_H_Hym_n_1', 're_H_Hym_d_0', 'si_G_Stron_0', 'si_G_Stron_1', 'si_G_Trich_0', 'si_G_Trich_1', 'si_G_Asc_0', 'si_G_Asc_1', 'si_G_Hook_0', 'si_G_Hook_1', 'si_H_Enter_0', 'si_H_Enter_1', 'si_H_schis_0', 'si_H_schis_1', 'si_H_hym_n_0', 'si_H_hym_n_1', 'si_H_hym_d_0', 'geohel_dom_G_ascar', 'geohel_dom_G_hoock', 'geohel_dom_G_sterco', 'geohel_dom_schistos', 're_G_stron_0', 're_G_stron_1', 'ind_tip1_G_0', 'ind_tip1_G_1', 'ind_tip1_H_0', 'ind_tip1_H_1'   ]
df_X = one_hot_predictors.drop(columns=bacteria_variables)
df_y = infeccion_piel

# %%
model = xgboost.train({"learning_rate": 0.01}, xgboost.DMatrix(df_X, label=df_y), 100)

# %%
explainer = shap.TreeExplainer(model)
shap_values = explainer.shap_values(df_X)

# %%
shap.summary_plot(shap_values, df_X, plot_type='dot', feature_names=df_X.columns)

# %%
shap.summary_plot(shap_values, df_X, plot_type='bar', feature_names=df_X.columns)

# %% [markdown]
# ## CON LINEAL

# %%
import shap
from sklearn.linear_model import LinearRegression
shap.initjs()
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script>!function(t){function e(r){if(n[r])return n[r].exports;var i=n[r]={i:r,l:!1,exports:{}};return t[r].call(i.exports,i,i.exports,e),i.l=!0,i.exports}var n={};return e.m=t,e.c=n,e.i=function(t){return t},e.d=function(t,n,r){e.o(t,n)||Object.defineProperty(t,n,{configurable:!1,enumerable:!0,get:r})},e.n=function(t){var n=t&&t.__esModule?function(){return t.default}:function(){return t};return e.d(n,"a",n),n},e.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},e.p="",e(e.s=410)}([function(t,e,n){"use strict";function r(t,e,n,r,o,a,u,c){if(i(e),!t){var s;if(void 0===e)s=new Error("Minified exception occurred; use the non-minified dev environment for the full error message and additional helpful warnings.");else{var l=[n,r,o,a,u,c],f=0;s=new Error(e.replace(/%s/g,function(){return l[f++]})),s.name="Invariant Violation"}throw s.framesToPop=1,s}}var i=function(t){};t.exports=r},function(t,e,n){"use strict
# ...

# %%
variables_de_bichos = ['sum_G_Stro', 'sum_G_Tric', 'sum_G_Asc', 'sum_G_HOOK', 'sum_H_Ente', 'sum_H_Schi', 'sum_H_Hym_', 'sum_H_Hy_1', 'riq_Geoh', 'riq_helm', 'p_G_Strong', 'p_G_Trich', 'p_G_Asc', 'p_G_HOOK', 'p_H_Enter', 'p_H_Schis', 'p_H_hym_n', 'p_H_hym_d', 'sh_geohel', 'sh_helm', 'Re_hous_nu', 'num_indiv', 'p_tip1_G', 'p_tip1_H', 'ind_inf_Ge', 'ind_inf_He', 'n_Geo_mean', 'n_Hel_mean', 'HOOKWORM_h', 'HGH_x_50', 'r_huev_hoo', 'n_geo_stde', 'n_Hel_stde', 're_hgh50', 'sum_hgh50', 're_G_trich_0', 're_G_trich_1', 're_G_Asc_0', 're_G_Asc_1', 're_G_Hook_0', 're_G_Hook_1', 're_H_Enter_0', 're_H_Enter_1', 're_H_Schis_0', 're_H_Schis_1', 're_H_Hym_n_0', 're_H_Hym_n_1', 're_H_Hym_d_0', 'si_G_Stron_0', 'si_G_Stron_1', 'si_G_Trich_0', 'si_G_Trich_1', 'si_G_Asc_0', 'si_G_Asc_1', 'si_G_Hook_0', 'si_G_Hook_1', 'si_H_Enter_0', 'si_H_Enter_1', 'si_H_schis_0', 'si_H_schis_1', 'si_H_hym_n_0', 'si_H_hym_n_1', 'si_H_hym_d_0', 'geohel_dom_G_ascar', 'geohel_dom_G_hoock', 'geohel_dom_G_sterco', 'geohel_dom_schistos', 're_G_stron_0', 're_G_stron_1', 'ind_tip1_G_0', 'ind_tip1_G_1', 'ind_tip1_H_0', 'ind_tip1_H_1'   ]
df_X = one_hot_predictors.drop(columns=variables_de_bichos)
df_y = infeccion_piel

# %%
X_train, X_test, y_train, y_test = train_test_split(df_X, df_y, test_size=0.2, random_state=7)

# %%
model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
explainer = shap.LinearExplainer(model, X_train)
shap_values = explainer.shap_values(X_test)
#X_test_array = X_test.toarray() # we need to pass a dense version for the plotting functions
# Out:
# /home/juansca/.local/lib/python3.6/site-packages/shap/explainers/linear.py:124: RuntimeWarning: invalid value encountered in true_divide
#   cov_inv_SiSi[:-1, :-1] = cov_inv_SS + np.outer(t, t) / u
# /home/juansca/.local/lib/python3.6/site-packages/shap/explainers/linear.py:125: RuntimeWarning: invalid value encountered in true_divide
#   cov_inv_SiSi[:-1, -1] = cov_inv_SiSi[-1,:-1] = -t / u
# /home/juansca/.local/lib/python3.6/site-packages/shap/explainers/linear.py:126: RuntimeWarning: divide by zero encountered in double_scalars
#   cov_inv_SiSi[-1, -1] = 1 / u
# /home/juansca/.local/lib/python3.6/site-packages/shap/explainers/linear.py:119: RuntimeWarning: invalid value encountered in matmul
#   t = np.matmul(cov_inv_SS, d)
# /home/juansca/.local/lib/python3.6/site-packages/shap/explainers/linear.py:124: RuntimeWarning: divide by zero encountered in true_divide
#   cov_inv_SiSi[:-1, :-1] = cov_inv_SS + np.outer(t, t) / u
# ...

# %%
shap.summary_plot(shap_values, X_test, plot_type='dot', feature_names=df_X.columns)

# %%
shap.summary_plot(shap_values, df_X, plot_type='bar', feature_names=df_X.columns)

# %% [markdown]
# ## Analizamos las features para INFECCION FECORAL

# %%
infeccion_fecoral.plot.hist()

# %%
import shap
import xgboost
shap.initjs()
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script>!function(t){function e(r){if(n[r])return n[r].exports;var i=n[r]={i:r,l:!1,exports:{}};return t[r].call(i.exports,i,i.exports,e),i.l=!0,i.exports}var n={};return e.m=t,e.c=n,e.i=function(t){return t},e.d=function(t,n,r){e.o(t,n)||Object.defineProperty(t,n,{configurable:!1,enumerable:!0,get:r})},e.n=function(t){var n=t&&t.__esModule?function(){return t.default}:function(){return t};return e.d(n,"a",n),n},e.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},e.p="",e(e.s=410)}([function(t,e,n){"use strict";function r(t,e,n,r,o,a,u,c){if(i(e),!t){var s;if(void 0===e)s=new Error("Minified exception occurred; use the non-minified dev environment for the full error message and additional helpful warnings.");else{var l=[n,r,o,a,u,c],f=0;s=new Error(e.replace(/%s/g,function(){return l[f++]})),s.name="Invariant Violation"}throw s.framesToPop=1,s}}var i=function(t){};t.exports=r},function(t,e,n){"use strict
# ...

# %%
from xgboost import XGBRegressor

# %%
df_y = infeccion_fecoral

# %%
model = xgboost.train({"learning_rate": 0.01}, xgboost.DMatrix(df_X, label=df_y), 100)

# %%
explainer = shap.TreeExplainer(model)
shap_values = explainer.shap_values(df_X)

# %%
shap.summary_plot(shap_values, df_X, plot_type='dot', feature_names=df_X.columns)

# %%
shap.summary_plot(shap_values, df_X, plot_type='bar', feature_names=df_X.columns)

# %% [markdown]
# ## Analizamos las features para Shanon G

# %%
infeccion_fecoral.plot.hist()

# %%
import shap
import xgboost
shap.initjs()
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script>!function(t){function e(r){if(n[r])return n[r].exports;var i=n[r]={i:r,l:!1,exports:{}};return t[r].call(i.exports,i,i.exports,e),i.l=!0,i.exports}var n={};return e.m=t,e.c=n,e.i=function(t){return t},e.d=function(t,n,r){e.o(t,n)||Object.defineProperty(t,n,{configurable:!1,enumerable:!0,get:r})},e.n=function(t){var n=t&&t.__esModule?function(){return t.default}:function(){return t};return e.d(n,"a",n),n},e.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},e.p="",e(e.s=410)}([function(t,e,n){"use strict";function r(t,e,n,r,o,a,u,c){if(i(e),!t){var s;if(void 0===e)s=new Error("Minified exception occurred; use the non-minified dev environment for the full error message and additional helpful warnings.");else{var l=[n,r,o,a,u,c],f=0;s=new Error(e.replace(/%s/g,function(){return l[f++]})),s.name="Invariant Violation"}throw s.framesToPop=1,s}}var i=function(t){};t.exports=r},function(t,e,n){"use strict
# ...

# %%
from xgboost import XGBRegressor

# %%
df_y = one_hot_predictors['sh_geohel']

# %%
model = xgboost.train({"learning_rate": 0.01}, xgboost.DMatrix(df_X, label=df_y), 100)

# %%
explainer = shap.TreeExplainer(model)
shap_values = explainer.shap_values(df_X)

# %%
shap.summary_plot(shap_values, df_X, plot_type='dot', feature_names=df_X.columns)

# %%
shap.summary_plot(shap_values, df_X, plot_type='bar', feature_names=df_X.columns)

# %% [markdown]
# ## Analizamos las features para Riquesa

# %%
infeccion_fecoral.plot.hist()

# %%
import shap
import xgboost
shap.initjs()
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script>!function(t){function e(r){if(n[r])return n[r].exports;var i=n[r]={i:r,l:!1,exports:{}};return t[r].call(i.exports,i,i.exports,e),i.l=!0,i.exports}var n={};return e.m=t,e.c=n,e.i=function(t){return t},e.d=function(t,n,r){e.o(t,n)||Object.defineProperty(t,n,{configurable:!1,enumerable:!0,get:r})},e.n=function(t){var n=t&&t.__esModule?function(){return t.default}:function(){return t};return e.d(n,"a",n),n},e.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},e.p="",e(e.s=410)}([function(t,e,n){"use strict";function r(t,e,n,r,o,a,u,c){if(i(e),!t){var s;if(void 0===e)s=new Error("Minified exception occurred; use the non-minified dev environment for the full error message and additional helpful warnings.");else{var l=[n,r,o,a,u,c],f=0;s=new Error(e.replace(/%s/g,function(){return l[f++]})),s.name="Invariant Violation"}throw s.framesToPop=1,s}}var i=function(t){};t.exports=r},function(t,e,n){"use strict
# ...

# %%
from xgboost import XGBRegressor

# %%
df_y = one_hot_predictors['riq_Geoh']

# %%
model = xgboost.train({"learning_rate": 0.01}, xgboost.DMatrix(df_X, label=df_y), 100)

# %%
explainer = shap.TreeExplainer(model)
shap_values = explainer.shap_values(df_X)

# %%
shap.summary_plot(shap_values, df_X, plot_type='dot', feature_names=df_X.columns)

# %%
shap.summary_plot(shap_values, df_X, plot_type='bar', feature_names=df_X.columns)

# %% [markdown]
# ## Metricas de interes
#
# - R2
# - MSE?
# - Corr
# - AIC
#
# ## Modelos
#
# - Lineal
# - xgboost

# %% [markdown]
# ## Force Plots
#
# -
